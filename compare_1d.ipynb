# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
alpha=[5,10,30,100]
bridge=[[3.6801,3.6865,3.6472],[3.7482,3.7710,3.7435],[3.8367,3.8349,3.8350],[3.8881,3.8881,3.8881]]
bridge=[[3.6392],[3.6584],[3.6758],[3.72905]]
primal_dual=3.529564 #3.529440
bridge=np.array(bridge).mean(axis=1)

# %%
plt.plot(alpha,bridge,"o-")
plt.xscale("log")
